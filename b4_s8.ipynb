# %%
#The movie was not good
#the movie was not bad.

# %%
#RNN carries Memory
#LSTM controls memory
#Attention focusses on the useful words

# %%
#CAT DOG MILK


#ANIMAL, food  , colour
[1,0.7,0.9]

[1,0.8,1]

[0.4, 1, 0.1]

# %%
sentence = "the movie was not good"
words = sentence.split()
memory = ""

for word in words:
    memory = memory + " " + word
    print("Current word:", word)
    print("Memory so far:", memory.strip())
# Out:
# Current word: the
# Memory so far: the
# Current word: movie
# Memory so far: the movie
# Current word: was
# Memory so far: the movie was
# Current word: not
# Memory so far: the movie was not
# Current word: good
# Memory so far: the movie was not good

# %%
#I grew up in France. I moved to india. I studied Engineering. I speak fluent ____

#LSTM - Controlled Memory
#LSTM= RNN + Gates + States

# %%
#cell state is the long term memory path
#hidden state is the current memory
#forget- Decides how much old info needs to be forgotten
#input gate- what new info to keep
#candidate memory- does the operation of storing info as per the input gate
#output gate- chooses what info to show

# %%
#binary classifier for lstm

import tensorflow as tf

model =tf.keras.Sequential([
    tf.keras.layers.Embedding(1000,8),#encoder
    tf.keras.layers.LSTM(16),#decoders
    tf.keras.layers.Dense(1, activation="sigmoid")#decoders

]

)

# %%
#ATTENTION
