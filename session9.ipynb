# %%
#I deposited money in the bank

#Query represent what the token is searching for
#key represent how that token can be matched
#value has the information that can be shared

# %%
#study_hours, attendance, marks

# %%
#in order to calculate attention the model creates 3 versions of each token

# %%
#Runner
#to go running
#is it raining outside (-2)
#Very good weather ( 3)



#bias
#if weather is good and I have motivation I will go for a run (1)
#lazy person (-1)

#I am a lazy person and it is raining outside
1+(weights) multipied by bias
1+(-2)*-1=1

#Motivated person
1(3)*1=3

# %%
I go to the river bank

# %%
QKV STORY
Sentence:
"The animal did not cross the road because it was tired."

Current token:
"it"

Query of "it":
"Which earlier token explains what I refer to?"

Key of "animal":
"I represent an entity that may be referred to later."

Strong Query-Key match:
"it" focuses strongly on "animal"

Value of "animal":
Information about the animal is passed into the representation of "it"

# %%
#QKV are divided into smaller groups called attention heads

# %%
#I deposited, money in the bank
#

# %%
MULTI-HEAD IDEA
Large Q, K, V vectors
        ↓ split
Head 1  Head 2  Head 3  ... Head 12
        ↓
Each head performs attention separately

pass the results to the next part of transformer block that is MLP

# %%
"He is cold."
"Visiting relatives can be annoying"

# %%
CAUSAL MASKING VISIBILITY
Token position 1 can see: 1
Token position 2 can see: 1, 2
Token position 3 can see: 1, 2, 3
Token position 4 can see: 1, 2, 3, 4

No position can see tokens to its right.

# %%
The cat did not cross the street because it was tired.


Raw scores of
cat=4.2
road=1
the=0.2

softmax
animal= 0.8
road= 0.15
the =0.05

# %%
GELU as a Club security guard (bouncer)

# %%
Data visualization empowers users to

possible raw logits
understand  = 8.2
create      = 6.4
banana      = -1.1

Higher logit means stronger current preference.

# %%
#VERBOSE

# %%
TOP K
FIXED NUMBER OF CANDIDATES
Token probabilities:
A = 0.40
B = 0.25
C = 0.15
D = 0.10
E = 0.06
F = 0.04

Top-k = 3:
Allowed: A, B, C
Removed: D, E, F

# %%
TOP P example
FLEXIBLE CANDIDATE COUNT
Sorted probabilities:
A = 0.40   cumulative = 0.40
B = 0.25   cumulative = 0.65
C = 0.15   cumulative = 0.80
D = 0.10   cumulative = 0.90

Top-p = 0.90:
Allowed: A, B, C, D
